# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import pandas as pd      
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = (7,4)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix, average_precision_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df_Female = pd.read_csv("ANSUR II FEMALE Public.csv")

# %%
df_Male = pd.read_csv("ANSUR II MALE Public.csv", encoding='latin-1')

# %%
df_Male.shape, df_Female.shape
# Out:
# ((4082, 108), (1986, 108))

# %%
df = pd.concat([df_Male, df_Female], join = "inner", ignore_index= True)

# inner join takes comman variables of the features. So Subjuctid and subjectid have dropped automatically.

# %%
df.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             266            1467                    337
# 1                             233            1395                    326
# 2                             287            1430                    341
# 3                             234            1347                    310
# 4                             250            1585                    372
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 222          1347                      253
# 1                 220          1293                      245
# 2                 230          1327                      256
# 3                 230          1239                      262
# 4                 247          1478                      267
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               202                401                        369
# 1               193                394                        338
# 2               196                427                        408
# 3               199                401                        359
# 4               224                435                        356
#
#    bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  \
# 0               274               493                  71               319
# 1               257               479                  67               344
# 2               261               544                  75               345
# 3               262               518                  73               328
# 4               263               524                  80               340
#
#    bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0                        291                 142                   979
# 1                        320                 135                   944
# 2                        330                 135                  1054
# 3                        309                 143                   991
# 4                        310                 138                  1029
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  \
# 0           240            882                619                     509
# 1           232            870                584                     468
# 2           258            901                623                     506
# 3           242            821                560                     437
# 4           275           1080                706                     567
#
#    calfcircumference  cervicaleheight  chestbreadth  chestcircumference  \
# 0                373             1535           291                1074
# 1                357             1471           269                1021
# 2                412             1501           288                1120
# 3                395             1423           296                1114
# 4                425             1684           304                1048
#
#    chestdepth  chestheight  crotchheight  crotchlengthomphalion  \
# 0         259         1292           877                    607
# 1         253         1244           851                    615
# 2         267         1288           854                    636
# 3         262         1205           769                    590
# 4         232         1452          1014                    682
#
#    crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                             351          36         71             19
# 1                             376          33         62             18
# 2                             359          40         61             23
# 3                             341          39         66             25
# 4                             382          32         56             19
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              247               802                    101         273
# 1              232               781                     98         263
# 2              237               810                    103         270
# 3              272               794                    106         267
# 4              188               814                    111         305
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  \
# 0                        349                         299
# 1                        348                         289
# 2                        355                         357
# 3                        352                         318
# 4                        399                         324
#
#    forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  \
# 0                    575                477                 1136           90
# 1                    523                476                 1096           86
# 2                    575                491                 1115           93
# 3                    593                467                 1034           91
# 4                    605                550                 1279           94
#
#    handcircumference  handlength  headbreadth  headcircumference  headlength  \
# 0                214         193          150                583         206
# 1                203         195          146                568         201
# 2                220         203          148                573         202
# 3                217         194          158                576         199
# 4                222         218          153                566         197
#
#    heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  \
# 0                     326           70         332                366
# 1                     334           72         312                356
# 2                     356           70         349                393
# 3                     341           68         338                367
# 4                     374           69         332                372
#
#    iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                1071                    685         422          441
# 1                1046                    620         441          447
# 2                1053                    665         462          475
# 3                 986                    640         458          461
# 4                1251                    675         481          505
#
#    kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   502                560                             500
# 1                   490                540                             488
# 2                   496                556                             482
# 3                   460                511                             452
# 4                   612                666                             585
#
#    lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                      77                      391                  118
# 1                      73                      371                  131
# 2                      72                      409                  123
# 3                      76                      393                  106
# 4                      85                      458                  135
#
#    neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                400                    436                           1447
# 1                380                    420                           1380
# 2                403                    434                           1447
# 3                407                    446                           1357
# 4                398                    430                           1572
#
#    palmlength  poplitealheight  radialestylionlength  shouldercircumference  \
# 0         113              437                   273                   1151
# 1         118              417                   254                   1119
# 2         121              431                   268                   1276
# 3         118              393                   249                   1155
# 4         132              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight Gender       Date Installation  \
# 0                 175          853   Male   4-Oct-10    Fort Hood
# 1                 167          815   Male   4-Oct-10    Fort Hood
# 2                 180          831   Male   4-Oct-10    Fort Hood
# 3                 176          793   Male  12-Oct-10    Fort Hood
# 4                 188          954   Male  12-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#    SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   1       NaN        1   41        71        180
# 1                   1       NaN        1   35        68        160
# 2                   2       NaN        2   42        68        205
# 3                   1       NaN        1   31        66        175
# 4                   2       NaN        2   21        77        213
#
#   WritingPreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand

# %%
df.duplicated().sum()

#we controled any duplicated values.. And we have no duplicate values.
# Out:
# 0

# %% [markdown]
# ## Explore Data

# %%
#Let's explore our data !

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Columns: 107 entries, abdominalextensiondepthsitting to WritingPreference
# dtypes: int64(98), object(9)
# memory usage: 5.0+ MB

# %%
df.isnull().sum()

#Just one column("Ethnicity") has a NaN values. And it's too much
# Out:
# abdominalextensiondepthsitting       0
# acromialheight                       0
# acromionradialelength                0
# anklecircumference                   0
# axillaheight                         0
# balloffootcircumference              0
# balloffootlength                     0
# biacromialbreadth                    0
# bicepscircumferenceflexed            0
# bicristalbreadth                     0
# bideltoidbreadth                     0
# bimalleolarbreadth                   0
# bitragionchinarc                     0
# bitragionsubmandibulararc            0
# bizygomaticbreadth                   0
# buttockcircumference                 0
# buttockdepth                         0
# buttockheight                        0
# buttockkneelength                    0
# buttockpopliteallength               0
# calfcircumference                    0
# cervicaleheight                      0
# chestbreadth                         0
# chestcircumference                   0
# chestdepth                           0
# chestheight                          0
# crotchheight                         0
# crotchlengthomphalion                0
# crotchlengthposterioromphalion       0
# earbreadth                           0
# earlength                            0
# earprotrusion                        0
# elbowrestheight                      0
# eyeheightsitting                     0
# footbreadthhorizontal                0
# footlength                           0
# forearmcenterofgriplength            0
# forearmcircumferenceflexed           0
# forearmforearmbreadth                0
# forearmhandlength                    0
# functionalleglength                  0
# handbreadth                          0
# handcircumference                    0
# handlength                           0
# headbreadth                          0
# headcircumference                    0
# headlength                           0
# heelanklecircumference               0
# heelbreadth                          0
# hipbreadth                           0
# hipbreadthsitting                    0
# iliocristaleheight                   0
# interpupillarybreadth                0
# interscyei                           0
# interscyeii                          0
# kneeheightmidpatella                 0
# kneeheightsitting                    0
# lateralfemoralepicondyleheight       0
# lateralmalleolusheight               0
# lowerthighcircumference              0
# mentonsellionlength                  0
# neckcircumference                    0
# neckcircumferencebase                0
# overheadfingertipreachsitting        0
# palmlength                           0
# poplitealheight                      0
# radialestylionlength                 0
# shouldercircumference                0
# shoulderelbowlength                  0
# shoulderlength                       0
# sittingheight                        0
# sleevelengthspinewrist               0
# sleeveoutseam                        0
# span                                 0
# stature                              0
# suprasternaleheight                  0
# tenthribheight                       0
# thighcircumference                   0
# thighclearance                       0
# thumbtipreach                        0
# tibialheight                         0
# tragiontopofhead                     0
# trochanterionheight                  0
# verticaltrunkcircumferenceusa        0
# waistbacklength                      0
# waistbreadth                         0
# waistcircumference                   0
# waistdepth                           0
# waistfrontlengthsitting              0
# waistheightomphalion                 0
# weightkg                             0
# wristcircumference                   0
# wristheight                          0
# Gender                               0
# Date                                 0
# Installation                         0
# Component                            0
# Branch                               0
# PrimaryMOS                           0
# SubjectsBirthLocation                0
# SubjectNumericRace                   0
# Ethnicity                         4647
# DODRace                              0
# Age                                  0
# Heightin                             0
# Weightlbs                            0
# WritingPreference                    0
# dtype: int64

# %%
df["Ethnicity"].value_counts(dropna= False)
# Out:
# NaN                                                   4647
# Mexican                                                357
# Puerto Rican                                           183
# Caribbean Islander                                     124
# Filipino                                                67
# Cherokee                                                65
# Korean                                                  53
# Dominican                                               32
# Chinese                                                 26
# Japanese                                                22
# Vietnamese                                              21
# Colombian                                               17
# Cuban                                                   17
# Arab or Middle Eastern                                  17
# Salvadoran                                              16
# East/Asian Indian                                       13
# Samoan                                                  11
# Mexican Puerto Rican                                    10
# Honduran                                                 9
# Laotian                                                  9
# Panamanian                                               9
# Peruvian                                                 9
# Dominican Puerto Rican                                   8
# Chippewa                                                 7
# Thai                                                     7
# Blackfoot                                                7
# Ecuadorian                                               7
# Hmong                                                    6
# Choctaw                                                  6
# Nicaraguan                                               6
# Creek                                                    5
# Blackfoot Cherokee                                       5
# Japanese Mexican                                         5
# Apache Cherokee                                          5
# Filipino Mexican                                         5
# Cambodian                                                4
# Navajo                                                   4
# Cherokee Puerto Rican                                    4
# Micronesian                                              4
# Lumbee                                                   4
# Cuban Puerto Rican                                       4
# Guamanian/Chamorro                                       4
# Guatemalan                                               4
# Guatemalan Mexican                                       4
# Potawatomi                                               4
# Mexican Salvadoran                                       4
# Chinese Filipino                                         3
# Cree                                                     3
# Cherokee Mexican                                         3
# Polynesian Samoan                                        3
# Ojibwe                                                   3
# Hawaiian                                                 3
# Comanche                                                 3
# Chilean Mexican                                          3
# Chinese Vietnamese                                       3
# Caribbean Islander Puerto Rican                          2
# Caribbean Islander Panamanian                            2
# Filipino Guamanian/Chamorro                              2
# Bolivian                                                 2
# Nepali                                                   2
# Chinese Thai                                             2
# Colombian Ecuadorian                                     2
# Cherokee Choctaw                                         2
# Kiowa                                                    2
# Hawaiian Polynesian                                      2
# Panamanian Puerto Rican                                  2
# Cuban Mexican                                            2
# Cherokee Japanese                                        2
# Malaysian                                                2
# Brazilian                                                2
# Ecuadorian Puerto Rican                                  2
# Seminole                                                 2
# Chickasaw                                                2
# Burmese                                                  2
# Eskimo                                                   2
# Cherokee Comanche                                        2
# Apache Blackfoot                                         2
# Apache                                                   2
# Belizean                                                 2
# Caribbean Islander East/Asian Indian                     2
# Shawnee                                                  2
# Honduran Nicaraguan                                      2
# Filipino Vietnamese                                      2
# Mescalero Apache                                         2
# Filipino Puerto Rican                                    1
# Puerto Rican Seneca                                      1
# Arab or Middle Eastern Venezuelan                        1
# Cherokee Choctaw Mexican                                 1
# Honduran Panamanian                                      1
# Argentine                                                1
# Lakota Sioux Oglala Sioux                                1
# Chinese Hmong                                            1
# Algonquin Navajo Penobscot                               1
# Caribbean Islander Chinese East/Asian Indian             1
# Cochiti Pueblo Mexican                                   1
# Tsimshian                                                1
# Belizean Dominican                                       1
# Chinese Japanese Korean Thai                             1
# Blackfoot Cherokee Shawnee                               1
# Choinumni Mono                                           1
# Chinese Hawaiian Japanese Polynesian                     1
# Blackfoot Cherokee Choctaw                               1
# Chickasaw Choctaw                                        1
# Apache Mexican                                           1
# Western Cherokee                                         1
# Osage                                                    1
# Guatemalan Salvadoran                                    1
# Choctaw Sioux                                            1
# Blackfoot Shawnee                                        1
# Choctaw Creek                                            1
# Mexican Turkish                                          1
# Choctaw Vietnamese                                       1
# Cherokee Hawaiian                                        1
# Cape Verdean                                             1
# Choctaw Cherokee                                         1
# Paraguayan                                               1
# Caddo Cheyenne Mexican                                   1
# Chinese Puerto Rican Seminole                            1
# Creek Samoan                                             1
# Omaha                                                    1
# Undisclosed Native American Tribe                        1
# Palauan                                                  1
# Cherokee Yaqui                                           1
# Creek Seminole                                           1
# Aztec Mexican                                            1
# Cheraw                                                   1
# Carolinian Guamanian/Chamorro                            1
# Fijian                                                   1
# Lenape Puerto Rican                                      1
# Cuban Venezuelan                                         1
# Peruvian Salvadoran                                      1
# Blackfoot Puerto Rican                                   1
# Caribbean Islander Vietnamese                            1
# Japanese Samoan                                          1
# Cheyenne                                                 1
# Arab or Middle Eastern Caribbean Islander Cherokee       1
# Chippewa Narragansett                                    1
# Cherokee Sioux                                           1
# Sri Lankan                                               1
# Mexican Venezuelan                                       1
# Taiwanese                                                1
# Puerto Rican Vietnamese                                  1
# Muscogee                                                 1
# Filipino Hawaiian                                        1
# Colombian Cuban                                          1
# Chilean                                                  1
# Miami                                                    1
# Dominican Salvadoran                                     1
# Mexican Zuni                                             1
# Chinook                                                  1
# Mexican Pomo                                             1
# Apache Kiowa Mexican                                     1
# Blackfoot Choctaw Sioux                                  1
# Guatemalan Honduran                                      1
# Mexican Yaqui                                            1
# Costa Rican Cuban                                        1
# Blackfoot Caribbean Islander Puerto Rican                1
# Houma                                                    1
# Cuban Unreadable Native American Tribe                   1
# Mexican Pima                                             1
# Ute                                                      1
# Aboriginal Guyanese                                      1
# Mexican Nicaraguan                                       1
# Costa Rican Salvadoran                                   1
# Salvadoran Venezuelan                                    1
# Métis Creole                                             1
# Hunkpapa Lakota                                          1
# Cheyenne River Sioux                                     1
# Argentine Mexican                                        1
# Chinese Mexican                                          1
# Cherokee Iroquois                                        1
# Dominican Korean                                         1
# Dominican Guyanese                                       1
# Navajo Sioux                                             1
# Sioux                                                    1
# Argentine Brazilian                                      1
# Cherokee Korean                                          1
# Chippewa Mexican                                         1
# Arab or Middle Eastern Honduran                          1
# Caribbean Islander Cherokee                              1
# Nicaraguan Salvadoran                                    1
# Guatemalan Puerto Rican                                  1
# Chinese Korean                                           1
# Armenian                                                 1
# Caribbean Islander Cuban                                 1
# Arab or Middle Eastern Cuban                             1
# Oneida                                                   1
# Chinese Japanese                                         1
# Filipino Hawaiian Puerto Rican                           1
# Dominican Ecuadorian Puerto Rican                        1
# Caribbean Islander Mexican                               1
# Cuban Laotian                                            1
# Filipino Japanese                                        1
# Filipino Hawaiian Japanese                               1
# Japanese Korean                                          1
# Indonesian Puerto Rican                                  1
# Cherokee Osage                                           1
# Laguna Pueblo Mexican Puerto Rican                       1
# Mexican Panamanian                                       1
# Colombian Puerto Rican                                   1
# Costa Rican                                              1
# Cambodian Vietnamese                                     1
# Turkish                                                  1
# Filipino Korean                                          1
# Blackfoot Mexican                                        1
# Lakota Sioux                                             1
# Cuban Salvadoran                                         1
# Caribbean Islander Dominican                             1
# Azorean                                                  1
# Apache Blackfoot Cherokee Crow                           1
# Name: Ethnicity, dtype: int64

# %%
df.drop(['Ethnicity'], axis=1, inplace=True)

# Ethnicity column is unneccasry column for ML model.

# %%
df.shape
# Out:
# (6068, 106)

# %%
df.DODRace.value_counts() # DODRace my target feature !!
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: DODRace, dtype: int64

# %%
ax =sns.countplot(data = df, x= "DODRace");
for i in ax.containers:
    ax.bar_label(i,fmt="%.2f");

# %% [markdown]
# Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %%
df = df[df.DODRace.isin([1,2,3])]

# %%
df.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             266            1467                    337
# 1                             233            1395                    326
# 2                             287            1430                    341
# 3                             234            1347                    310
# 4                             250            1585                    372
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 222          1347                      253
# 1                 220          1293                      245
# 2                 230          1327                      256
# 3                 230          1239                      262
# 4                 247          1478                      267
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               202                401                        369
# 1               193                394                        338
# 2               196                427                        408
# 3               199                401                        359
# 4               224                435                        356
#
#    bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  \
# 0               274               493                  71               319
# 1               257               479                  67               344
# 2               261               544                  75               345
# 3               262               518                  73               328
# 4               263               524                  80               340
#
#    bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0                        291                 142                   979
# 1                        320                 135                   944
# 2                        330                 135                  1054
# 3                        309                 143                   991
# 4                        310                 138                  1029
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  \
# 0           240            882                619                     509
# 1           232            870                584                     468
# 2           258            901                623                     506
# 3           242            821                560                     437
# 4           275           1080                706                     567
#
#    calfcircumference  cervicaleheight  chestbreadth  chestcircumference  \
# 0                373             1535           291                1074
# 1                357             1471           269                1021
# 2                412             1501           288                1120
# 3                395             1423           296                1114
# 4                425             1684           304                1048
#
#    chestdepth  chestheight  crotchheight  crotchlengthomphalion  \
# 0         259         1292           877                    607
# 1         253         1244           851                    615
# 2         267         1288           854                    636
# 3         262         1205           769                    590
# 4         232         1452          1014                    682
#
#    crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                             351          36         71             19
# 1                             376          33         62             18
# 2                             359          40         61             23
# 3                             341          39         66             25
# 4                             382          32         56             19
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              247               802                    101         273
# 1              232               781                     98         263
# 2              237               810                    103         270
# 3              272               794                    106         267
# 4              188               814                    111         305
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  \
# 0                        349                         299
# 1                        348                         289
# 2                        355                         357
# 3                        352                         318
# 4                        399                         324
#
#    forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  \
# 0                    575                477                 1136           90
# 1                    523                476                 1096           86
# 2                    575                491                 1115           93
# 3                    593                467                 1034           91
# 4                    605                550                 1279           94
#
#    handcircumference  handlength  headbreadth  headcircumference  headlength  \
# 0                214         193          150                583         206
# 1                203         195          146                568         201
# 2                220         203          148                573         202
# 3                217         194          158                576         199
# 4                222         218          153                566         197
#
#    heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  \
# 0                     326           70         332                366
# 1                     334           72         312                356
# 2                     356           70         349                393
# 3                     341           68         338                367
# 4                     374           69         332                372
#
#    iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                1071                    685         422          441
# 1                1046                    620         441          447
# 2                1053                    665         462          475
# 3                 986                    640         458          461
# 4                1251                    675         481          505
#
#    kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   502                560                             500
# 1                   490                540                             488
# 2                   496                556                             482
# 3                   460                511                             452
# 4                   612                666                             585
#
#    lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                      77                      391                  118
# 1                      73                      371                  131
# 2                      72                      409                  123
# 3                      76                      393                  106
# 4                      85                      458                  135
#
#    neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                400                    436                           1447
# 1                380                    420                           1380
# 2                403                    434                           1447
# 3                407                    446                           1357
# 4                398                    430                           1572
#
#    palmlength  poplitealheight  radialestylionlength  shouldercircumference  \
# 0         113              437                   273                   1151
# 1         118              417                   254                   1119
# 2         121              431                   268                   1276
# 3         118              393                   249                   1155
# 4         132              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight Gender       Date Installation  \
# 0                 175          853   Male   4-Oct-10    Fort Hood
# 1                 167          815   Male   4-Oct-10    Fort Hood
# 2                 180          831   Male   4-Oct-10    Fort Hood
# 3                 176          793   Male  12-Oct-10    Fort Hood
# 4                 188          954   Male  12-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#    SubjectNumericRace  DODRace  Age  Heightin  Weightlbs WritingPreference
# 0                   1        1   41        71        180        Right hand
# 1                   1        1   35        68        160         Left hand
# 2                   2        2   42        68        205         Left hand
# 3                   1        1   31        66        175        Right hand
# 4                   2        2   21        77        213        Right hand

# %%
df.reset_index(drop=True, inplace = True)

# %%
df.DODRace.value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# Name: DODRace, dtype: int64

# %%
df["DODRace"] = df.DODRace.map({
    1: "White",
    2: "Black",
    3: "Hispanic"
})

# %%
colors = sns.color_palette('pastel')[0:5]
label =df.DODRace.value_counts().index
plt.pie(df.DODRace.value_counts(),labels=label, colors=colors, autopct="%0.1f%%", shadow=True)
plt.title("DODRace",size=15);

# %% [markdown]
#  SubjectNumericRace:
# a single or multi-digit code indicating a subject’s self-reported race or races (verified through interview). Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian, 5 = Native American, 6 = Pacific Islander, 8 = Other
#
#  DODRace:
# Department of Defense Race; a single digit indicating a subject’s self-reported preferred single race where selecting multiple races is not an option. This variable is intended to be comparable to the Defense Manpower Data Center demographic data. Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian, 5 = Native American, 6 = Pacific Islander, 8 = Other

# %%
df[["SubjectNumericRace","DODRace"]] #they are totaly same features.I can drop one of them.
# Out:
#       SubjectNumericRace   DODRace
# 0                      1     White
# 1                      1     White
# 2                      2     Black
# 3                      1     White
# 4                      2     Black
# ...                  ...       ...
# 5764                   3  Hispanic
# 5765                   3  Hispanic
# 5766                   2     Black
# 5767                   3  Hispanic
# 5768                   3  Hispanic
#
# [5769 rows x 2 columns]

# %%
df.drop("SubjectNumericRace", axis = 1, inplace = True)

# %%
df.shape
# Out:
# (5769, 105)

# %%
df_object = df.select_dtypes('object')
df_object.head()
# Out:
#   Gender       Date Installation     Component                  Branch  \
# 0   Male   4-Oct-10    Fort Hood  Regular Army             Combat Arms
# 1   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support
# 2   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support
# 3   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support
# 4   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support
#
#   PrimaryMOS SubjectsBirthLocation DODRace WritingPreference
# 0        19D          North Dakota   White        Right hand
# 1        68W              New York   White         Left hand
# 2        68W              New York   Black         Left hand
# 3        88M             Wisconsin   White        Right hand
# 4        92G        North Carolina   Black        Right hand

# %%
for col in df_object:
    print(f"{col:<25}:", df[col].nunique())
# Out:
# Gender                   : 2
# Date                     : 253
# Installation             : 12
# Component                : 3
# Branch                   : 3
# PrimaryMOS               : 281
# SubjectsBirthLocation    : 136
# DODRace                  : 3
# WritingPreference        : 3

# %%
df.groupby(["Component"])["DODRace"].value_counts(normalize=True)
# Out:
# Component            DODRace
# Army National Guard  White       0.711546
#                      Black       0.191408
#                      Hispanic    0.097046
# Army Reserve         White       0.550725
#                      Black       0.251208
#                      Hispanic    0.198068
# Regular Army         White       0.616920
#                      Black       0.252792
#                      Hispanic    0.130288
# Name: DODRace, dtype: float64

# %%
df.groupby(["Component"])["DODRace"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='Component,DODRace'>

# %%
df.groupby(["Component", "Branch"])["DODRace"].value_counts(normalize=True)
# Out:
# Component            Branch                  DODRace
# Army National Guard  Combat Arms             White       0.802835
#                                              Black       0.101804
#                                              Hispanic    0.095361
#                      Combat Service Support  White       0.668855
#                                              Black       0.227571
#                                              Hispanic    0.103574
#                      Combat Support          White       0.684783
#                                              Black       0.234783
#                                              Hispanic    0.080435
# Army Reserve         Combat Arms             White       0.833333
#                                              Hispanic    0.166667
#                      Combat Service Support  White       0.602941
#                                              Hispanic    0.220588
#                                              Black       0.176471
#                      Combat Support          Black       0.430769
#                                              White       0.415385
#                                              Hispanic    0.153846
# Regular Army         Combat Arms             White       0.713499
#                                              Hispanic    0.157025
#                                              Black       0.129477
#                      Combat Service Support  White       0.602378
#                                              Black       0.270145
#                                              Hispanic    0.127477
#                      Combat Support          White       0.549650
#                                              Black       0.341259
#                                              Hispanic    0.109091
# Name: DODRace, dtype: float64

# %%
df.drop(columns=["Date","Installation","Component","Branch","PrimaryMOS","Weightlbs", "Heightin"], inplace = True )

# %%
df.shape
# Out:
# (5769, 98)

# %% [markdown]
# ## MultiCollinearty

# %%
df_numeric = df.select_dtypes(include = np.number)
df_numeric.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             266            1467                    337
# 1                             233            1395                    326
# 2                             287            1430                    341
# 3                             234            1347                    310
# 4                             250            1585                    372
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 222          1347                      253
# 1                 220          1293                      245
# 2                 230          1327                      256
# 3                 230          1239                      262
# 4                 247          1478                      267
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               202                401                        369
# 1               193                394                        338
# 2               196                427                        408
# 3               199                401                        359
# 4               224                435                        356
#
#    bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  \
# 0               274               493                  71               319
# 1               257               479                  67               344
# 2               261               544                  75               345
# 3               262               518                  73               328
# 4               263               524                  80               340
#
#    bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0                        291                 142                   979
# 1                        320                 135                   944
# 2                        330                 135                  1054
# 3                        309                 143                   991
# 4                        310                 138                  1029
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  \
# 0           240            882                619                     509
# 1           232            870                584                     468
# 2           258            901                623                     506
# 3           242            821                560                     437
# 4           275           1080                706                     567
#
#    calfcircumference  cervicaleheight  chestbreadth  chestcircumference  \
# 0                373             1535           291                1074
# 1                357             1471           269                1021
# 2                412             1501           288                1120
# 3                395             1423           296                1114
# 4                425             1684           304                1048
#
#    chestdepth  chestheight  crotchheight  crotchlengthomphalion  \
# 0         259         1292           877                    607
# 1         253         1244           851                    615
# 2         267         1288           854                    636
# 3         262         1205           769                    590
# 4         232         1452          1014                    682
#
#    crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                             351          36         71             19
# 1                             376          33         62             18
# 2                             359          40         61             23
# 3                             341          39         66             25
# 4                             382          32         56             19
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              247               802                    101         273
# 1              232               781                     98         263
# 2              237               810                    103         270
# 3              272               794                    106         267
# 4              188               814                    111         305
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  \
# 0                        349                         299
# 1                        348                         289
# 2                        355                         357
# 3                        352                         318
# 4                        399                         324
#
#    forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  \
# 0                    575                477                 1136           90
# 1                    523                476                 1096           86
# 2                    575                491                 1115           93
# 3                    593                467                 1034           91
# 4                    605                550                 1279           94
#
#    handcircumference  handlength  headbreadth  headcircumference  headlength  \
# 0                214         193          150                583         206
# 1                203         195          146                568         201
# 2                220         203          148                573         202
# 3                217         194          158                576         199
# 4                222         218          153                566         197
#
#    heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  \
# 0                     326           70         332                366
# 1                     334           72         312                356
# 2                     356           70         349                393
# 3                     341           68         338                367
# 4                     374           69         332                372
#
#    iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                1071                    685         422          441
# 1                1046                    620         441          447
# 2                1053                    665         462          475
# 3                 986                    640         458          461
# 4                1251                    675         481          505
#
#    kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   502                560                             500
# 1                   490                540                             488
# 2                   496                556                             482
# 3                   460                511                             452
# 4                   612                666                             585
#
#    lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                      77                      391                  118
# 1                      73                      371                  131
# 2                      72                      409                  123
# 3                      76                      393                  106
# 4                      85                      458                  135
#
#    neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                400                    436                           1447
# 1                380                    420                           1380
# 2                403                    434                           1447
# 3                407                    446                           1357
# 4                398                    430                           1572
#
#    palmlength  poplitealheight  radialestylionlength  shouldercircumference  \
# 0         113              437                   273                   1151
# 1         118              417                   254                   1119
# 2         121              431                   268                   1276
# 3         118              393                   249                   1155
# 4         132              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight  Age
# 0                 175          853   41
# 1                 167          815   35
# 2                 180          831   42
# 3                 176          793   31
# 4                 188          954   21

# %%
df_numeric.corr()[(df_numeric.corr()>= 0.9) & (df_numeric.corr() < 1)].any().any()
# Out:
# True

# %%
df_numeric.corr()[(df_numeric.corr()<= -0.9) & (df_numeric.corr() > -1)].any().any()
# Out:
# False

# %%
def color_red(val):
    
    if (val > 0.90 and val < 1) or (val < -0.90 and val > -1):
        color = 'red'
    else:
        color = 'black'
    return f'color: {color}'
df_numeric.corr().style.applymap(color_red)
# Out:
# <style type="text/css">
# #T_4a3a6_row0_col0, #T_4a3a6_row0_col1, #T_4a3a6_row0_col2, #T_4a3a6_row0_col3, #T_4a3a6_row0_col4, #T_4a3a6_row0_col5, #T_4a3a6_row0_col6, #T_4a3a6_row0_col7, #T_4a3a6_row0_col8, #T_4a3a6_row0_col9, #T_4a3a6_row0_col10, #T_4a3a6_row0_col11, #T_4a3a6_row0_col12, #T_4a3a6_row0_col13, #T_4a3a6_row0_col14, #T_4a3a6_row0_col15, #T_4a3a6_row0_col16, #T_4a3a6_row0_col17, #T_4a3a6_row0_col18, #T_4a3a6_row0_col19, #T_4a3a6_row0_col20, #T_4a3a6_row0_col21, #T_4a3a6_row0_col22, #T_4a3a6_row0_col23, #T_4a3a6_row0_col24, #T_4a3a6_row0_col25, #T_4a3a6_row0_col26, #T_4a3a6_row0_col27, #T_4a3a6_row0_col28, #T_4a3a6_row0_col29, #T_4a3a6_row0_col30, #T_4a3a6_row0_col31, #T_4a3a6_row0_col32, #T_4a3a6_row0_col33, #T_4a3a6_row0_col34, #T_4a3a6_row0_col35, #T_4a3a6_row0_col36, #T_4a3a6_row0_col37, #T_4a3a6_row0_col38, #T_4a3a6_row0_col39, #T_4a3a6_row0_col40, #T_4a3a6_row0_col41, #T_4a3a6_row0_col42, #T_4a3a6_row0_col43, #T_4a3a6_row0_col44, #T_4a3a6_row0_col45, #T_4a3a6_row0_col46, #T_4a3a6_row0_col47, #T_4a3a6_row0_col48, #T_4a3a6_row0_col49, #T_4a3a6_row0_col50, #T_4a3a6_row0_col51, #T_4a3a6_row0_col52, #T_4a3a6_row0_col53, #T_4a3a6_row0_col54, #T_4a3a6_row0_col55, #T_4a3a6_row0_col56, #T_4a3a6_row0_col57, #T_4a3a6_row0_col58, #T_4a3a6_row0_col59, #T_4a3a6_row0_col60, #T_4a3a6_row0_col61, #T_4a3a6_row0_col62, #T_4a3a6_row0_col63, #T_4a3a6_row0_col64, #T_4a3a6_row0_col65, #T_4a3a6_row0_col66, #T_4a3a6_row0_col67, #T_4a3a6_row0_col68, #T_4a3a6_row0_col69, #T_4a3a6_row0_col70, #T_4a3a6_row0_col71, #T_4a3a6_row0_col72, #T_4a3a6_row0_col73, #T_4a3a6_row0_col74, #T_4a3a6_row0_col75, #T_4a3a6_row0_col76, #T_4a3a6_row0_col77, #T_4a3a6_row0_col78, #T_4a3a6_row0_col79, #T_4a3a6_row0_col80, #T_4a3a6_row0_col81, #T_4a3a6_row0_col82, #T_4a3a6_row0_col83, #T_4a3a6_row0_col84, #T_4a3a6_row0_col85, #T_4a3a6_row0_col88, #T_4a3a6_row0_col89, #T_4a3a6_row0_col90, #T_4a3a6_row0_col91, #T_4a3a6_row0_col92, #T_4a3a6_row0_col93, #T_4a3a6_row1_col0, #T_4a3a6_row1_col1, #T_4a3a6_row1_col2, #T_4a3a6_row1_col3, #T_4a3a6_row1_col5, #T_4a3a6_row1_col6, #T_4a3a6_row1_col7, #T_4a3a6_row1_col8, #T_4a3a6_row1_col9, #T_4a3a6_row1_col10, #T_4a3a6_row1_col11, #T_4a3a6_row1_col12, #T_4a3a6_row1_col13, #T_4a3a6_row1_col14, #T_4a3a6_row1_col15, #T_4a3a6_row1_col16, #T_4a3a6_row1_col17, #T_4a3a6_row1_col18, #T_4a3a6_row1_col19, #T_4a3a6_row1_col20, #T_4a3a6_row1_col22, #T_4a3a6_row1_col23, #T_4a3a6_row1_col24, #T_4a3a6_row1_col26, #T_4a3a6_row1_col27, #T_4a3a6_row1_col28, #T_4a3a6_row1_col29, #T_4a3a6_row1_col30, #T_4a3a6_row1_col31, #T_4a3a6_row1_col32, #T_4a3a6_row1_col33, #T_4a3a6_row1_col34, #T_4a3a6_row1_col35, #T_4a3a6_row1_col36, #T_4a3a6_row1_col37, #T_4a3a6_row1_col38, #T_4a3a6_row1_col39, #T_4a3a6_row1_col40, #T_4a3a6_row1_col41, #T_4a3a6_row1_col42, #T_4a3a6_row1_col43, #T_4a3a6_row1_col44, #T_4a3a6_row1_col45, #T_4a3a6_row1_col46, #T_4a3a6_row1_col47, #T_4a3a6_row1_col48, #T_4a3a6_row1_col49, #T_4a3a6_row1_col50, #T_4a3a6_row1_col52, #T_4a3a6_row1_col53, #T_4a3a6_row1_col54, #T_4a3a6_row1_col55, #T_4a3a6_row1_col57, #T_4a3a6_row1_col58, #T_4a3a6_row1_col59, #T_4a3a6_row1_col60, #T_4a3a6_row1_col61, #T_4a3a6_row1_col62, #T_4a3a6_row1_col63, #T_4a3a6_row1_col64, #T_4a3a6_row1_col65, #T_4a3a6_row1_col66, #T_4a3a6_row1_col67, #T_4a3a6_row1_col68, #T_4a3a6_row1_col69, #T_4a3a6_row1_col70, #T_4a3a6_row1_col71, #T_4a3a6_row1_col72, #T_4a3a6_row1_col73, #T_4a3a6_row1_col77, #T_4a3a6_row1_col78, #T_4a3a6_row1_col79, #T_4a3a6_row1_col80, #T_4a3a6_row1_col81, #T_4a3a6_row1_col82, #T_4a3a6_row1_col83, #T_4a3a6_row1_col84, #T_4a3a6_row1_col85, #T_4a3a6_row1_col86, #T_4a3a6_row1_col87, #T_4a3a6_row1_col88, #T_4a3a6_row1_col90, #T_4a3a6_row1_col91, #T_4a3a6_row1_col93, #T_4a3a6_row2_col0, #T_4a3a6_row2_col1, #T_4a3a6_row2_col2, #T_4a3a6_row2_col3, #T_4a3a6_row2_col4, #T_4a3a6_row2_col5, #T_4a3a6_row2_col6, #T_4a3a6_row2_col7, #T_4a3a6_row2_col8, #T_4a3a6_row2_col9, #T_4a3a6_row2_col10, #T_4a3a6_row2_col11, #T_4a3a6_row2_col12, #T_4a3a6_row2_col13, #T_4a3a6_row2_col14, #T_4a3a6_row2_col1 ...

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
df.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             266            1467                    337
# 1                             233            1395                    326
# 2                             287            1430                    341
# 3                             234            1347                    310
# 4                             250            1585                    372
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 222          1347                      253
# 1                 220          1293                      245
# 2                 230          1327                      256
# 3                 230          1239                      262
# 4                 247          1478                      267
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               202                401                        369
# 1               193                394                        338
# 2               196                427                        408
# 3               199                401                        359
# 4               224                435                        356
#
#    bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  \
# 0               274               493                  71               319
# 1               257               479                  67               344
# 2               261               544                  75               345
# 3               262               518                  73               328
# 4               263               524                  80               340
#
#    bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0                        291                 142                   979
# 1                        320                 135                   944
# 2                        330                 135                  1054
# 3                        309                 143                   991
# 4                        310                 138                  1029
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  \
# 0           240            882                619                     509
# 1           232            870                584                     468
# 2           258            901                623                     506
# 3           242            821                560                     437
# 4           275           1080                706                     567
#
#    calfcircumference  cervicaleheight  chestbreadth  chestcircumference  \
# 0                373             1535           291                1074
# 1                357             1471           269                1021
# 2                412             1501           288                1120
# 3                395             1423           296                1114
# 4                425             1684           304                1048
#
#    chestdepth  chestheight  crotchheight  crotchlengthomphalion  \
# 0         259         1292           877                    607
# 1         253         1244           851                    615
# 2         267         1288           854                    636
# 3         262         1205           769                    590
# 4         232         1452          1014                    682
#
#    crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                             351          36         71             19
# 1                             376          33         62             18
# 2                             359          40         61             23
# 3                             341          39         66             25
# 4                             382          32         56             19
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              247               802                    101         273
# 1              232               781                     98         263
# 2              237               810                    103         270
# 3              272               794                    106         267
# 4              188               814                    111         305
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  \
# 0                        349                         299
# 1                        348                         289
# 2                        355                         357
# 3                        352                         318
# 4                        399                         324
#
#    forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  \
# 0                    575                477                 1136           90
# 1                    523                476                 1096           86
# 2                    575                491                 1115           93
# 3                    593                467                 1034           91
# 4                    605                550                 1279           94
#
#    handcircumference  handlength  headbreadth  headcircumference  headlength  \
# 0                214         193          150                583         206
# 1                203         195          146                568         201
# 2                220         203          148                573         202
# 3                217         194          158                576         199
# 4                222         218          153                566         197
#
#    heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  \
# 0                     326           70         332                366
# 1                     334           72         312                356
# 2                     356           70         349                393
# 3                     341           68         338                367
# 4                     374           69         332                372
#
#    iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                1071                    685         422          441
# 1                1046                    620         441          447
# 2                1053                    665         462          475
# 3                 986                    640         458          461
# 4                1251                    675         481          505
#
#    kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   502                560                             500
# 1                   490                540                             488
# 2                   496                556                             482
# 3                   460                511                             452
# 4                   612                666                             585
#
#    lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                      77                      391                  118
# 1                      73                      371                  131
# 2                      72                      409                  123
# 3                      76                      393                  106
# 4                      85                      458                  135
#
#    neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                400                    436                           1447
# 1                380                    420                           1380
# 2                403                    434                           1447
# 3                407                    446                           1357
# 4                398                    430                           1572
#
#    palmlength  poplitealheight  radialestylionlength  shouldercircumference  \
# 0         113              437                   273                   1151
# 1         118              417                   254                   1119
# 2         121              431                   268                   1276
# 3         118              393                   249                   1155
# 4         132              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight Gender SubjectsBirthLocation DODRace  Age  \
# 0                 175          853   Male          North Dakota   White   41
# 1                 167          815   Male              New York   White   35
# 2                 180          831   Male              New York   Black   42
# 3                 176          793   Male             Wisconsin   White   31
# 4                 188          954   Male        North Carolina   Black   21
#
#   WritingPreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand

# %%
df0 = df.copy()

# %%
X = df.drop(columns="DODRace")
y = df.DODRace

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101, stratify=y)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4615, 97)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 97)
# Test target shape    :  (1154,)

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
cat = X_train.select_dtypes("object").columns
cat
# Out:
# Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object')

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler

column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       remainder=MinMaxScaler())

# %%
from sklearn.pipeline import Pipeline
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

pipe_log_model = Pipeline(steps=operations)

# %%
pipe_log_model.fit(X_train,y_train)
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[239  14   7]
#  [  5 111  20]
#  [ 25  89 644]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.92      0.90       260
#     Hispanic       0.52      0.82      0.63       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 971   37   30]
#  [  20  456   67]
#  [  57  362 2615]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.94      0.93      1038
#     Hispanic       0.53      0.84      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.91      0.88      0.88      4615

# %%
plot_confusion_matrix(pipe_log_model,X_test,y_test);

# %%
scoring = {"precision_Hispanic" : make_scorer(precision_score, average = None, labels =["Hispanic"]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =["Hispanic"]),
           "f1_Hispanic" : make_scorer(f1_score, average = None, labels =["Hispanic"])}

# %%
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_precision_Hispanic     0.490303
# train_precision_Hispanic    0.533167
# test_recall_Hispanic        0.773333
# train_recall_Hispanic       0.838958
# test_f1_Hispanic            0.599420
# train_f1_Hispanic           0.651966
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
recall_Hispanic =  make_scorer(recall_score, average=None, labels=["Hispanic"])

# %%
param_grid = {
    "log__C": [0.5, 1],
    'log__penalty': ["l1", "l2"],
    'log__solver': ['liblinear', 'lbfgs'],
}

# %%
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

model = Pipeline(steps=operations)

log_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              cv=10,
                              n_jobs=-1,
                              return_train_score=True)

# %%
log_model_grid.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
# ...
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# /Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/numpy_pickle.py:230: UserWarning: The memmapped array [[ 208  298  246 ...  197  220  237]
#  [1393 1497 1502 ... 1491 1346 1461]
#  [ 325  335  353 ...  340  308  346]
#  ...
#  [ 165  180  168 ...  167  152  173]
#  [ 806  889  906 ...  897  790  849]
#  [  25   33   36 ...   21   23   29]] loaded from the file /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/joblib_memmapping_folder_39088_1110172f454245d3b7654f557e008cad_7f03c2c315024280b276b7b8f69eb941/39088-140354041711152-f20b869b1d234e2590c3a22a10ea477e.pkl is not not bytes aligned. This may cause segmentation faults if this memmapped array is used in some libraries like BLAS or PyTorch. To get rid of this warning, regenerate your pickle file with joblib >= 1.2.0. See https://github.com/joblib/joblib/issues/563 for more details
#   warnings.warn(message)
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                                        ('log',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=10000,
#                                                            random_state=101))]),
#              n_jobs=-1,
#              param_grid={'log__C': [0.5, 1], 'log__penalty': ['l1', 'l2'],
#                          'log__solver': ['liblinear', 'lbfgs']},
#              return_train_score=True,
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
log_model_grid.best_estimator_
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                 ('log',
#                  LogisticRegression(C=1, class_weight='balanced',
#                                     max_iter=10000, random_state=101))])

# %%
log_model_grid.best_params_
# Out:
# {'log__C': 1, 'log__penalty': 'l2', 'log__solver': 'lbfgs'}

# %%
log_model_grid.best_index_
# Out:
# 7

# %%
pd.DataFrame(log_model_grid.cv_results_).loc[3, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score      0.7733
# mean_train_score    0.82689
# Name: 3, dtype: object

# %% [markdown]
# ### Cross Validate

# %%
from sklearn.model_selection import cross_validate

operations = [("scaler", MinMaxScaler()), ("logistic", LogisticRegression())]

model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision_weighted','recall_weighted',
                                                                   'f1_weighted'], cv = 5, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/pb/pznfcs350993c7spml7tbnv00000gp/T/ipykernel_39088/1767219313.py in <module>
#       5 model = Pipeline(steps=operations)
#       6
# ----> 7 scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision_weighted','recall_weighted',
#       8                                                                    'f1_weighted'], cv = 5, return_train_score=True)
#       9 df_scores = pd.DataFrame(scores, index = range(1, 11))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     283     )
#     284
# --> 285     _warn_or_raise_about_fit_failures(results, error_score)
#     286
#     287     # For callabe scoring, the return type is only know after calling. If the
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in _warn_or_raise_about_fit_failures(results, error_score)
#     365                 f"Below are more details about the failures:\n{fit_errors_summary}"
#     366             )
# --> 367             raise ValueError(all_fits_failed_message)
#     368
#     369         else:
#
# ValueError:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py", line 420, in fit
#     return self.partial_fit(X, y)
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py", line 457, in partial_fit
#     X = self._validate_data(
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 577, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 856, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/ruveydekaygisiz/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py", line 2064, in __array__
#     return np.asarray(self._values, dtype=dtype)
# ValueError: could not convert string to float: 'Male'

# %% [markdown]
# ### With Best Parameters (GridsearchCV)

# %%
from sklearn.model_selection import GridSearchCV

# %%
operations = [("scaler", MinMaxScaler()), ("logistic", LogisticRegression())]

model = Pipeline(steps=operations)

# %%
penalty = ["l1", "l2"]
C = [0.01, 0.1, 1, 5, 16, 19, 22, 25]

param_grid = {"logistic__penalty" : penalty,
             "logistic__C" : C}

# %%
grid_model = GridSearchCV(model, param_grid = param_grid, cv=5, return_train_score=True)

# %%
grid_model.fit(X_train,y_train)

# %%
grid_model.best_params_

# %%
grid_model.best_estimator_

# %%
grid_model.best_index_

# %%
pd.DataFrame(grid_model.cv_results_).loc[9, ["mean_test_score", "mean_train_score"]]

# %%
grid_model.best_score_

# %%
y_pred = grid_model.predict(X_test)
y_pred

# %%
plot_confusion_matrix(grid_model, X_test, y_test)

# %%
eval_metric(grid_model, X_train, y_train, X_test, y_test)

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve
from scikitplot.metrics import plot_precision_recall


operations = [("scaler", MinMaxScaler()), ("logistic", LogisticRegression(C=16))]

model = Pipeline(steps=operations)

model.fit(X_train, y_train)

y_pred_proba = model.predict_proba(X_test)
    
plot_roc(y_test, y_pred_proba)
plt.show();

# %%
from sklearn.metrics import average_precision_score, roc_auc_score

y_test_dummies = pd.get_dummies(y_test).values

roc_auc_score(y_test_dummies[:, 1], y_pred_proba[:, 1])

# %% [markdown]
# ## Precision Recall Curve

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve
from scikitplot.metrics import plot_precision_recall


operations = [("scaler", MinMaxScaler()), ("logistic", LogisticRegression(C=16))]

model = Pipeline(steps=operations)

model.fit(X_train, y_train)

y_pred_proba = model.predict_proba(X_test)
    
plot_precision_recall(y_test, y_pred_proba)
plt.show();

# %%
from sklearn.metrics import average_precision_score, roc_auc_score

y_test_dummies = pd.get_dummies(y_test).values

average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])

# %% [markdown]
# ## Over Sampling

# %%
#conda install -c conda-forge imbalanced-learn

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(random_state=0)
X_randomover, y_randomover = oversample.fit_resample(X_train, y_train)

from collections import Counter
print(sorted(Counter(y_randomover).items()))

# %%
from sklearn.preprocessing import StandardScaler

# %%
operations = [("scaler", StandardScaler()), ("logistic", LogisticRegression())]

pipe_model = Pipeline(steps=operations)

pipe_model.fit(X_randomover, y_randomover)

# %%
y_pred = pipe_model.predict(X_test)

# %%
plot_confusion_matrix(pipe_model, X_test, y_test)

# %%
eval_metric(pipe_model, X_train, y_train, X_test, y_test)

# %% [markdown]
# ## Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler
# transform the dataset
ranUnSample = RandomUnderSampler(random_state=0)
X_ranUnSample, y_ranUnSample = ranUnSample.fit_resample(X_train, y_train)

from collections import Counter
print(sorted(Counter(y_ranUnSample).items()))

# %%
operations = [("scaler", StandardScaler()), ("logistic", LogisticRegression())]

pipe_model = Pipeline(steps=operations)

pipe_model.fit(X_ranUnSample, y_ranUnSample)

# %%
y_pred = pipe_model.predict(X_test)
y_pred

# %%
plot_confusion_matrix(pipe_model, X_test, y_test)

# %%
eval_metric(pipe_model, X_train, y_train, X_test, y_test)

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
recall_Hispanic =  make_scorer(recall_score, average=None, labels=["Hispanic"])

# %%
operations = [("scaler", StandardScaler()), ("logistic", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

model = Pipeline(steps=operations)

log_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              cv=10,
                              n_jobs=-1,
                              return_train_score=True)

# %%
param_grid = {
    "log__C": [0.5, 1],
    'log__penalty': ["l1", "l2"],
    'log__solver': ['liblinear', 'lbfgs'],
}

# %%
grid_model.fit(X_train,y_train)

# %%
log_model_grid.best_estimator_

# %%
log_model_grid.best_params_

# %%
grid_model.best_index_

# %%
pd.DataFrame(log_model_grid.cv_results_).loc[7, ["mean_test_score", "mean_train_score"]]

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)

# %%
from yellowbrick.classifier import PrecisionRecallCurve

operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=42))]

model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, 
    classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve
from scikitplot.metrics import plot_precision_recall


operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=42))]

model = Pipeline(steps=operations)

model.fit(X_train, y_train)

y_pred_proba = model.predict_proba(X_test)
    
plot_precision_recall(y_test, y_pred_proba)
plt.show();

# %%
from sklearn.metrics import average_precision_score

y_test_dummies = pd.get_dummies(y_test).values

average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])

# %%
viz.score_#["Hispanic"]

# %%
y_pred = log_model_grid.predict(X_test)

log_AP = viz.score_["Hispanic"]
log_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
log_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %% [markdown]
# ###  SVC Model GridsearchCV

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %% [markdown]
# ### RF Model GridsearchCV

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %% [markdown]
# ## SVC Over/Under Sampling

# %% [markdown]
# ## Xgboost Over/ Under Sampling

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, y_pred)

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)

# %% [markdown]
# #  SHAP
#
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
# !pip install shap

# %%
import shap
explainer = shap.Explainer(log_model,X_train)
start_index = 203
end_index = 204
shap_values = explainer.shap_values(X_test[start_index:end_index])

# %%
shap_values

# %%
print(shap_values[0].shape)

# %%
# %% >> Visualize local predictions
shap.initjs()
# Force plot
prediction = log_model.predict(X_test[start_index:end_index])[0]
print(f"The log_model predicted: {prediction}")
shap.force_plot(explainer.expected_value[1],
                shap_values[1],
                X_test[start_index:end_index], # for values
                feature_names= X.columns,)

# %%
shap.summary_plot(shap_values, X_train,max_display=300,feature_names = X.columns)

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
